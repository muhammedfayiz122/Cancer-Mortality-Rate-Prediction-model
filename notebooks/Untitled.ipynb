# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cancer_reg.csv", encoding='ISO-8859-1')
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   TARGET_deathRate         3047 non-null   float64
#  3   incidenceRate            3047 non-null   float64
#  4   medIncome                3047 non-null   int64
#  5   popEst2015               3047 non-null   int64
#  6   povertyPercent           3047 non-null   float64
#  7   studyPerCap              3047 non-null   float64
#  8   binnedInc                3047 non-null   object
#  9   MedianAge                3047 non-null   float64
#  10  MedianAgeMale            3047 non-null   float64
#  11  MedianAgeFemale          3047 non-null   float64
#  12  Geography                3047 non-null   object
#  13  AvgHouseholdSize         3047 non-null   float64
# ...

# %%
df.describe()
# Out:
#         avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medIncome    popEst2015  povertyPercent  studyPerCap    MedianAge  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# ...

# %%
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
df.columns
# Out:
# Index(['avgAnnCount', 'avgDeathsPerYear', 'TARGET_deathRate', 'incidenceRate',
#        'medIncome', 'popEst2015', 'povertyPercent', 'studyPerCap', 'binnedInc',
#        'MedianAge', 'MedianAgeMale', 'MedianAgeFemale', 'Geography',
#        'AvgHouseholdSize', 'PercentMarried', 'PctNoHS18_24', 'PctHS18_24',
#        'PctSomeCol18_24', 'PctBachDeg18_24', 'PctHS25_Over',
#        'PctBachDeg25_Over', 'PctEmployed16_Over', 'PctUnemployed16_Over',
#        'PctPrivateCoverage', 'PctPrivateCoverageAlone', 'PctEmpPrivCoverage',
#        'PctPublicCoverage', 'PctPublicCoverageAlone', 'PctWhite', 'PctBlack',
#        'PctAsian', 'PctOtherRace', 'PctMarriedHouseholds', 'BirthRate'],
#       dtype='object')

# %%
X = df.drop('TARGET_deathRate', axis=1)
X.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  incidenceRate  medIncome  popEst2015  \
# 0       1397.0               469          489.8      61898      260131
# 1        173.0                70          411.6      48127       43269
# 2        102.0                50          349.7      49348       21026
# 3        427.0               202          430.4      44243       75882
# 4         57.0                26          350.1      49955       10321
#
#    povertyPercent  studyPerCap           binnedInc  MedianAge  MedianAgeMale  \
# 0            11.2   499.748204   (61494.5, 125635]       39.3           36.9
# 1            18.6    23.111234  (48021.6, 51046.4]       33.0           32.2
# 2            14.6    47.560164  (48021.6, 51046.4]       45.0           44.0
# 3            17.1   342.637253    (42724.4, 45201]       42.8           42.2
# 4            12.5     0.000000  (48021.6, 51046.4]       48.3           47.8
#
#    ...  PctPrivateCoverageAlone PctEmpPrivCoverage  PctPublicCoverage  \
# ...

# %%
X.isnull().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            2285
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          152
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     609
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# PctBlack                      0
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   incidenceRate            3047 non-null   float64
#  3   medIncome                3047 non-null   int64
#  4   popEst2015               3047 non-null   int64
#  5   povertyPercent           3047 non-null   float64
#  6   studyPerCap              3047 non-null   float64
#  7   binnedInc                3047 non-null   object
#  8   MedianAge                3047 non-null   float64
#  9   MedianAgeMale            3047 non-null   float64
#  10  MedianAgeFemale          3047 non-null   float64
#  11  Geography                3047 non-null   object
#  12  AvgHouseholdSize         3047 non-null   float64
#  13  PercentMarried           3047 non-null   float64
# ...

# %%
X[X.columns[7]].str[1:-1].str.split(',')[:].str[0].astype(float)
# Out:
# 0       61494.5
# 1       48021.6
# 2       48021.6
# 3       42724.4
# 4       48021.6
#          ...
# 3042    45201.0
# 3043    48021.6
# 3044    51046.4
# 3045    48021.6
# 3046    40362.7
# Name: binnedInc, Length: 3047, dtype: float64

# %%
X[X.columns[7]].str.extract(r'(\d+\.?\d*)').astype(float)
# Out:
#             0
# 0     61494.5
# 1     48021.6
# 2     48021.6
# 3     42724.4
# 4     48021.6
# ...       ...
# 3042  45201.0
# 3043  48021.6
# 3044  51046.4
# 3045  48021.6
# 3046  40362.7
#
# [3047 rows x 1 columns]

# %%
X['binnedInc_0'] = X[X.columns[7]].str[1:-1].str.strip("").str.split(',')[:].str[0].astype(float)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   incidenceRate            3047 non-null   float64
#  3   medIncome                3047 non-null   int64
#  4   popEst2015               3047 non-null   int64
#  5   povertyPercent           3047 non-null   float64
#  6   studyPerCap              3047 non-null   float64
#  7   binnedInc                3047 non-null   object
#  8   MedianAge                3047 non-null   float64
#  9   MedianAgeMale            3047 non-null   float64
#  10  MedianAgeFemale          3047 non-null   float64
#  11  Geography                3047 non-null   object
#  12  AvgHouseholdSize         3047 non-null   float64
#  13  PercentMarried           3047 non-null   float64
# ...

# %%
X['binnedInc_1'] = X[X.columns[7]].str[1:-1].str.split(',').str[1].astype(float)

# %%
X.drop(X.columns[7], inplace = True, axis=1)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   incidenceRate            3047 non-null   float64
#  3   medIncome                3047 non-null   int64
#  4   popEst2015               3047 non-null   int64
#  5   povertyPercent           3047 non-null   float64
#  6   studyPerCap              3047 non-null   float64
#  7   MedianAge                3047 non-null   float64
#  8   MedianAgeMale            3047 non-null   float64
#  9   MedianAgeFemale          3047 non-null   float64
#  10  Geography                3047 non-null   object
#  11  AvgHouseholdSize         3047 non-null   float64
#  12  PercentMarried           3047 non-null   float64
#  13  PctNoHS18_24             3047 non-null   float64
# ...

# %%
X["binnedInc"] = X[X.columns[32]] + X[X.columns[33]] / 2

# %%
X.drop([X.columns[32], X.columns[33]], axis = 1, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   incidenceRate            3047 non-null   float64
#  3   medIncome                3047 non-null   int64
#  4   popEst2015               3047 non-null   int64
#  5   povertyPercent           3047 non-null   float64
#  6   studyPerCap              3047 non-null   float64
#  7   MedianAge                3047 non-null   float64
#  8   MedianAgeMale            3047 non-null   float64
#  9   MedianAgeFemale          3047 non-null   float64
#  10  Geography                3047 non-null   object
#  11  AvgHouseholdSize         3047 non-null   float64
#  12  PercentMarried           3047 non-null   float64
#  13  PctNoHS18_24             3047 non-null   float64
# ...

# %%
X["County"] = X[X.columns[10]].str.split(",").str[0]
X["State"] = X[X.columns[10]].str.split(",").str[1]

# %%
X.drop("Geography", axis=1, inplace=True)

# %%
X_modified = X.interpolate()
X_modified.isnull().sum()
X_modified['PctPrivateCoverageAlone']
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_1556\4043945120.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   X_modified = X.interpolate()
# 0        NaN
# 1       53.8
# 2       43.5
# 3       40.3
# 4       43.9
#         ...
# 3042    54.9
# 3043    53.3
# 3044    52.6
# 3045    56.3
# 3046    60.3
# Name: PctPrivateCoverageAlone, Length: 3047, dtype: float64

# %%
X_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   incidenceRate            3047 non-null   float64
#  3   medIncome                3047 non-null   int64
#  4   popEst2015               3047 non-null   int64
#  5   povertyPercent           3047 non-null   float64
#  6   studyPerCap              3047 non-null   float64
#  7   MedianAge                3047 non-null   float64
#  8   MedianAgeMale            3047 non-null   float64
#  9   MedianAgeFemale          3047 non-null   float64
#  10  AvgHouseholdSize         3047 non-null   float64
#  11  PercentMarried           3047 non-null   float64
#  12  PctNoHS18_24             3047 non-null   float64
#  13  PctHS18_24               3047 non-null   float64
# ...

# %%
X_modified[X_modified.columns[32]] = X_modified[X_modified.columns[32]].str.strip()

# %%
X_modified[X_modified.columns[32]][0]
# Out:
# 'Kitsap County'

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
X_modified.columns[-2]
# Out:
# 'County'

# %%
X_encoded = X_modified
X_encoded[X_encoded.columns[-2]] = encoder.fit_transform(X_encoded[X_encoded.columns[-2]])
X_encoded.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  incidenceRate  medIncome  popEst2015  \
# 0       1397.0               469          489.8      61898      260131
# 1        173.0                70          411.6      48127       43269
# 2        102.0                50          349.7      49348       21026
# 3        427.0               202          430.4      44243       75882
# 4         57.0                26          350.1      49955       10321
#
#    povertyPercent  studyPerCap  MedianAge  MedianAgeMale  MedianAgeFemale  \
# 0            11.2   499.748204       39.3           36.9             41.7
# 1            18.6    23.111234       33.0           32.2             33.7
# 2            14.6    47.560164       45.0           44.0             45.8
# 3            17.1   342.637253       42.8           42.2             43.4
# 4            12.5     0.000000       48.3           47.8             48.9
#
#    ...  PctPublicCoverageAlone   PctWhite  PctBlack  PctAsian  PctOtherRace  \
# ...

# %%
X_encoded[X_encoded.columns[-1]] = encoder.fit_transform(X_encoded[X_encoded.columns[-1]])
X_encoded.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  incidenceRate  medIncome  popEst2015  \
# 0       1397.0               469          489.8      61898      260131
# 1        173.0                70          411.6      48127       43269
# 2        102.0                50          349.7      49348       21026
# 3        427.0               202          430.4      44243       75882
# 4         57.0                26          350.1      49955       10321
#
#    povertyPercent  studyPerCap  MedianAge  MedianAgeMale  MedianAgeFemale  \
# 0            11.2   499.748204       39.3           36.9             41.7
# 1            18.6    23.111234       33.0           32.2             33.7
# 2            14.6    47.560164       45.0           44.0             45.8
# 3            17.1   342.637253       42.8           42.2             43.4
# 4            12.5     0.000000       48.3           47.8             48.9
#
#    ...  PctPublicCoverageAlone   PctWhite  PctBlack  PctAsian  PctOtherRace  \
# ...

# %%
#onehot encoding
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('geography', OneHotEncoder(), [32] )],remainder= "passthrough")

# %%
X_encoded = ct.fit_transform(X_encoded)
X_encoded
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 101073 stored elements and shape (3047, 1852)>

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
y = df['TARGET_deathRate']
y.isnull().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_encoded[:,1:], y, test_size=0.2, random_state=42)

# %%
X_test[:]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 20235 stored elements and shape (610, 1851)>

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 model.score(X_test, y_test)
#
# File ~\Desktop\cancer_mortality_rate_prediction\venv\Lib\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\Desktop\cancer_mortality_rate_prediction\venv\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
# ...

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 X_train.head()
#
# AttributeError: 'csr_matrix' object has no attribute 'head'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
